# %% [markdown]
# # Extração de Dados

# %% [raw]
# pip install pandera

# %%
import pandas as pd
import numpy as np
import chardet
import pandera as pa

# %%
df = pd.read_csv('ocorrencias.csv', sep=',')
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
with open('ocorrencias.csv', 'rb') as rawdata: 
    result = chardet.detect(rawdata.read(6000))
print(result)
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
df = pd.read_csv('ocorrencias.csv', encoding='ISO-8859-1')
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.dtypes
# Out:
# codigo_ocorrencia            int64
# codigo_ocorrencia2           int64
# ocorrencia_classificacao    object
# ocorrencia_cidade           object
# ocorrencia_uf               object
# ocorrencia_aerodromo        object
# ocorrencia_dia              object
# ocorrencia_hora             object
# total_recomendacoes          int64
# dtype: object

# %% [raw]
# # A coluna ocorrencia_dia está como 'object' e precisamos converte-la para o tipo data.

# %%
df = pd.read_csv('ocorrencias.csv', encoding='ISO-8859-1', parse_dates=['ocorrencia_dia'])
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
df.ocorrencia_dia.dt.month
# Out:
# 0       3
# 1       3
# 2       3
# 3       4
# 4       5
#        ..
# 6109    8
# 6110    8
# 6111    8
# 6112    8
# 6113    8
# Name: ocorrencia_dia, Length: 6114, dtype: int64

# %%
df.ocorrencia_dia.head()
# Out:
# 0   2010-03-01
# 1   2010-03-01
# 2   2010-03-01
# 3   2010-04-01
# 4   2010-05-01
# Name: ocorrencia_dia, dtype: datetime64[ns]

# %% [markdown]
# ![](ocorrencia_dia.PNG)

# %%
# Como podemos perceber na imagem acima o dia esta na frente do mês, 
# vamos efetuar sua correção com o parametro 'dayfirst'

# %%
df = pd.read_csv('ocorrencias.csv', encoding='ISO-8859-1', parse_dates=['ocorrencia_dia'], dayfirst=True)
df.ocorrencia_dia.head()
# Out:
# 0   2010-01-03
# 1   2010-01-03
# 2   2010-01-03
# 3   2010-01-04
# 4   2010-01-05
# Name: ocorrencia_dia, dtype: datetime64[ns]

# %% [markdown]
# # Limpeza de Dados

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %%
np.unique(df['ocorrencia_uf'])
# Out:
# array(['***', 'AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA',
#        'MG', 'MS', 'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO',
#        'RR', 'RS', 'SC', 'SE', 'SP', 'TO'], dtype=object)

# %%
np.unique(df['ocorrencia_aerodromo'])
# Out:
# array(['###!', '####', '****', '*****', '5JTI', '9PAA', '9PBS', '9PFC',
#        '9PFX', '9PHD', '9PSD', 'SBAE', 'SBAN', 'SBAQ', 'SBAR', 'SBAT',
#        'SBAU', 'SBBE', 'SBBH', 'SBBI', 'SBBP', 'SBBQ', 'SBBR', 'SBBU',
#        'SBBV', 'SBBW', 'SBBZ', 'SBCA', 'SBCB', 'SBCF', 'SBCG', 'SBCJ',
#        'SBCP', 'SBCR', 'SBCT', 'SBCX', 'SBCY', 'SBCZ', 'SBDN', 'SBEG',
#        'SBEK', 'SBFE', 'SBFI', 'SBFL', 'SBFN', 'SBFS', 'SBFZ', 'SBGL',
#        'SBGO', 'SBGP', 'SBGR', 'SBGV', 'SBGW', 'SBHT', 'SBIH', 'SBIL',
#        'SBIP', 'SBIT', 'SBIZ', 'SBJA', 'SBJC', 'SBJD', 'SBJF', 'SBJI',
#        'SBJP', 'SBJR', 'SBJU', 'SBJV', 'SBKG', 'SBKP', 'SBLE', 'SBLJ',
#        'SBLO', 'SBMA', 'SBMD', 'SBME', 'SBMG', 'SBMK', 'SBML', 'SBMO',
#        'SBMQ', 'SBMS', 'SBMT', 'SBMY', 'SBNF', 'SBNM', 'SBNT', 'SBNV',
#        'SBPA', 'SBPB', 'SBPC', 'SBPF', 'SBPJ', 'SBPK', 'SBPL', 'SBPN',
#        'SBPP', 'SBPR', 'SBPS', 'SBPV', 'SBQV', 'SBRB', 'SBRD', 'SBRF',
# ...

# %% [raw]
# Como podemos verificar temos as seguintes inconsistentes ###!, ####, ****, *****, **, NULL

# %% [raw]
# Agora vamos carregar nossos dados já executando a limpeza e validação em poucas linhas de comando

# %%
valores_ausentes = ['###!', '####', '****', '*****', '***', '**', 'NULL']
df = pd.read_csv('ocorrencias.csv', encoding='ISO-8859-1', parse_dates=['ocorrencia_dia'], dayfirst=True, na_values=valores_ausentes)
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39707               39707          INCIDENTE GRAVE
# 8              39156               39156          INCIDENTE GRAVE
# 9              39711               39711          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# ...

# %% [markdown]
# # Validação

# %% [raw]
# Agora vamos validar com o pacote pandera nosso Data Frame

# %%
schema = pa.DataFrameSchema(
    {
       'codigo_ocorrencia':pa.Column(pa.Int),
        'codigo_ocorrencia2':pa.Column(pa.Int),
        'ocorrencia_classificacao':pa.Column(pa.String),
        'ocorrencia_cidade':pa.Column(pa.String),
        'ocorrencia_uf':pa.Column(pa.String, pa.Check.str_length(2,2), nullable=True),
        'ocorrencia_aerodromo':pa.Column(pa.String, nullable=True),
        'ocorrencia_dia':pa.Column(pa.DateTime),
        'ocorrencia_hora':pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9]):([0-5][0-9])?$'), nullable=True),
        'total_recomendacoes':pa.Column(pa.Int)
    }
)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %% [markdown]
# # Transformação

# %% [raw]
# Vamos unir as colunas ocorrencia dia e hora para facilitar seu armazenamento

# %%
df['ocorrencia_dia_hora'] = pd.to_datetime(df.ocorrencia_dia.astype(str) + ' ' + df.ocorrencia_hora)
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39707               39707          INCIDENTE GRAVE
# 8              39156               39156          INCIDENTE GRAVE
# 9              39711               39711          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# ...

# %% [raw]
# Agora vamos remover a coluna 'ocorrencia_dia' e 'ocorrencia_hora' pois elas já foram agurpadas em uma só

# %%
df.drop(columns=['ocorrencia_dia', 'ocorrencia_hora'], inplace=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  total_recomendacoes  \
# 0      RIO DE JANEIRO            RJ                  NaN                    0
# 1               BELÉM            PA                 SBBE                    0
# 2      RIO DE JANEIRO            RJ                 SBRJ                    0
# 3  LUCAS DO RIO VERDE            MT                  NaN                    0
# 4             PELOTAS            RS                 SBPK                    0
#
#   ocorrencia_dia_hora
# 0 2010-01-03 12:00:00
# 1 2010-01-03 11:05:00
# 2 2010-01-03 03:00:00
# ...

# %% [markdown]
# # Salvando os dados

# %% [raw]
# Vamos atribuir a um arquivo '.csv' para depois efetuarmos seu carregamento

# %%
df.to_csv('ocorrencia_etl.csv', encoding='latin1', na_rep='N/A', index=None, date_format='%d/%m/%Y %H:%M')
